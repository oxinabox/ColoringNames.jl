# %%
reload("TensorFlow")
reload("ColoringNames")
# Out:
# WARNING: replacing module TensorFlow.
# WARNING: replacing module ColoringNames
# WARNING: Method definition rpad(Array{#T<:Any, 1}, Integer) in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:4 overwritten in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:4.
# WARNING: Method definition rpad(Array{#T<:Any, 1}, Integer, #T<:Any) in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:4 overwritten in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:4.
# WARNING: Method definition rstrip(Array{#T<:Any, 1}) in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:25 overwritten in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:25.
# WARNING: Method definition rstrip(Array{#T<:Any, 1}, #T<:Any) in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:25 overwritten in module ColoringNames at /home/ubuntu/.julia/v0.5/ColoringNames/src/util.jl:25.

# %%
using ColoringNames
using JLD
using MLLabelUtils
using MLDataPattern
using Plots
using DataFrames
using Glob
# Out:
# INFO: Recompiling stale cache file /home/ubuntu/.julia/lib/v0.5/Glob.ji for module Glob.

# %%
full_param_path = "../models/good/1706031148_sib0.5/params.jld"
full_params = load(full_param_path)
#
#
full_mdl = restore(TermToColorDistributionNetwork, full_param_path, full_params["model_path"])
full_params["dev_set_results"]
# Out:
# 2017-06-15 07:43:13.241943: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-06-15 07:43:13.242072: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-06-15 07:43:13.242084: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-06-15 07:43:13.242096: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Dict{Symbol,Float64} with 5 entries:
#   :perp        => 27.1822
#   :mse_to_peak => 0.142116
#   :perp_sat    => 41.6243
#   :perp_hue    => 15.347
#   :perp_val    => 31.44

# %%
extrapo_params_path = "../models/good/extrapolate_sib0.5/params.jld"
extrapo_params = load(extrapo_params_path)
#
#
extrapo_mdl = restore(TermToColorDistributionNetwork, extrapo_params_path)

extrapo_params["dev_set_results"]

# %%
empirical_params_path = "/mnt_obj/color/models/noml_validation/sib0.5_or64/params_with_model.jld"
empirical_params = load(empirical_params_path)
empiri_mdl = empirical_params["model"];

# %%
@assert full_mdl.encoding.label == extrapo_mdl.encoding.label
@assert full_mdl.embedding_dim==extrapo_mdl.embedding_dim
@assert full_mdl.hidden_layer_size==extrapo_mdl.hidden_layer_size

# %%
full_cldata = load_monroe_data()
extrapo_cldata = extrapolation_dataset(full_cldata, extrapo_params["eval_texts"])
# Out:
# UndefVarError: SwiftService not defined
#
#  in #load_monroe_data#16(::Bool, ::Bool, ::Function) at /home/ubuntu/.julia/v0.5/ColoringNames/src/load_data.jl:20
#  in load_monroe_data() at /home/ubuntu/.julia/v0.5/ColoringNames/src/load_data.jl:20

# %%
evaluate(full_mdl, extrapo_cldata.test.terms_padded, extrapo_cldata.test.colors)
# Out:
# UndefVarError: extrapo_cldata not defined

# %%
df = DataFrame()
df[:name]=Float64[]
df
# Out:
# 0×1 DataFrames.DataFrame

# %%
DataFrames.
# Out:
# syntax: incomplete: premature end of input

# %%
function per_color_eval(cldata, factor; mdls...)
    df = DataFrame(name=String[])
    col_name(ii) = Symbol(factor, :_, ii)
    for (ii, mdl) in mdls
        df[col_name(ii)] = Float64[]
    end
    for (color_name, inds) in labelmap(cldata.texts)
        terms_padded, color = datasubset((cldata.terms_padded, cldata.colors), inds, (ObsDim.Last(), ObsDim.First()))
        row = Dict{Symbol, Any}(:name=>color_name)
        for (ii, mdl) in mdls
            res = evaluate(mdl, terms_padded, color)
            row[col_name(ii)] = res[factor]
        end
        push!(df, row)
    end
    df
end

pc_df = per_color_eval(extrapo_cldata.dev, :perp; extrapo_mdl = extrapo_mdl, full_mdl=full_mdl)
# Out:
# 100×3 DataFrames.DataFrame
# │ Row │ name                  │ perp_extrapo_mdl │ perp_full_mdl │
# ├─────┼───────────────────────┼──────────────────┼───────────────┤
# │ 1   │ "violet pink"         │ 23.4617          │ 24.304        │
# │ 2   │ "deep violet"         │ 35.4082          │ 35.6296       │
# │ 3   │ "bright yellow"       │ 11.9954          │ 10.9669       │
# │ 4   │ "reddish"             │ 27.5516          │ 26.1546       │
# │ 5   │ "violet red"          │ 36.4614          │ 29.3801       │
# │ 6   │ "yellowish brown"     │ 21.9973          │ 21.7244       │
# │ 7   │ "red-pink"            │ 21.7047          │ 20.4859       │
# │ 8   │ "rosy pink"           │ 23.0174          │ 22.5348       │
# │ 9   │ "yellowish"           │ 19.1352          │ 18.7839       │
# │ 10  │ "orange-yellow"       │ 26.6676          │ 15.4337       │
# │ 11  │ "purplish red"        │ 26.7787          │ 24.8608       │
# ⋮
# │ 89  │ "pinky red"           │ 20.3469          │ 19.2575       │
# │ 90  │ "orangish red"        │ 14.6196          │ 14.6698       │
# │ 91  │ "brownish green"      │ 33.3851          │ 27.827        │
# │ 92  │ "yellowish orange"    │ 14.6763          │ 13.3793       │
# │ 93  │ "greyish pink"        │ 26.6962          │ 25.6338       │
# │ 94  │ "purplish grey"       │ 38.2277          │ 35.226        │
# │ 95  │ "light greenish blue" │ 112.289          │ 27.733        │
# │ 96  │ "brownish grey"       │ 39.2355          │ 29.0025       │
# │ 97  │ "lightish blue"       │ 29.628           │ 29.1356       │
# │ 98  │ "orangish"            │ 16.9777          │ 18.9435       │
# │ 99  │ "red-purple"          │ 35.8531          │ 32.748        │
# │ 100 │ "deep rose"           │ 21.9378          │ 22.3471       │

# %%
showall(sort!(pc_df; cols=:perp_extrapo_mdl))
# Out:
# 100×3 DataFrames.DataFrame
# │ Row │ name                  │ perp_extrapo_mdl │ perp_full_mdl │
# ├─────┼───────────────────────┼──────────────────┼───────────────┤
# │ 1   │ "bright orange"       │ 11.5113          │ 11.3518       │
# │ 2   │ "bright yellow"       │ 11.9954          │ 10.9669       │
# │ 3   │ "orangish red"        │ 14.6196          │ 14.6698       │
# │ 4   │ "yellowish orange"    │ 14.6763          │ 13.3793       │
# │ 5   │ "orangey red"         │ 14.9967          │ 15.315        │
# │ 6   │ "deep orange"         │ 15.217           │ 14.2928       │
# │ 7   │ "lime yellow"         │ 15.6669          │ 15.7607       │
# │ 8   │ "reddish orange"      │ 16.707           │ 16.1241       │
# │ 9   │ "orangish"            │ 16.9777          │ 18.9435       │
# │ 10  │ "orangish brown"      │ 17.4502          │ 17.0241       │
# │ 11  │ "bright yellow green" │ 17.9712          │ 17.0592       │
# │ 12  │ "brownish orange"     │ 18.1686          │ 18.1671       │
# │ 13  │ "pink-red"            │ 18.1865          │ 18.047        │
# │ 14  │ "darkish red"         │ 18.9808          │ 19.2213       │
# │ 15  │ "yellowish"           │ 19.1352          │ 18.7839       │
# │ 16  │ "brownish yellow"     │ 19.3698          │ 18.8399       │
# │ 17  │ "brown-orange"        │ 19.4206          │ 18.7557       │
# │ 18  │ "bright lime"         │ 19.701           │ 19.0172       │
# │ 19  │ "bright light green"  │ 19.981           │ 18.8626       │
# │ 20  │ "light bright green"  │ 19.9911          │ 19.3303       │
# │ 21  │ "orangey brown"       │ 20.3156          │ 19.5198       │
# │ 22  │ "pinky red"           │ 20.3469          │ 19.2575       │
# │ 23  │ "pale yellow-green"   │ 20.4657          │ 18.5972       │
# │ 24  │ "very pale blue"      │ 20.6627          │ 21.586        │
# │ 25  │ "bright light blue"   │ 21.3362          │ 21.1321       │
# │ 26  │ "red-pink"            │ 21.7047          │ 20.4859       │
# │ 27  │ "deep rose"           │ 21.9378          │ 22.3471       │
# │ 28  │ "yellowish brown"     │ 21.9973          │ 21.7244       │
# │ 29  │ "pale lime green"     │ 22.2932          │ 20.1738       │
# │ 30  │ "reddy brown"         │ 22.852           │ 21.6902       │
# │ 31  │ "rosy pink"           │ 23.0174          │ 22.5348       │
# │ 32  │ "brownish red"        │ 23.1386          │ 22.349        │
# │ 33  │ "lightish red"        │ 23.1675          │ 22.0227       │
# │ 34  │ "light lime"          │ 23.2338          │ 22.1671       │
# │ 35  │ "violet pink"         │ 23.4617          │ 24.304        │
# │ 36  │ "brown yellow"        │ 23.5857          │ 21.8428       │
# │ 37  │ "pale lime"           │ 23.672           │ 24.1788       │
# │ 38  │ "bluey purple"        │ 23.8497          │ 22.6263       │
# │ 39  │ "pinkish orange"      │ 24.1365          │ 19.9881       │
# │ 40  │ "light yellow green"  │ 24.6736          │ 23.34         │
# │ 41  │ "greeny brown"        │ 25.2834          │ 24.4105       │
# │ 42  │ "brown-red"           │ 25.5192          │ 25.4824       │
# │ 43  │ "bright olive"        │ 25.5536          │ 25.7405       │
# │ 44  │ "olive brown"         │ 25.7581          │ 24.7495       │
# │ 45  │ "dark lime"           │ 26.1413          │ 27.7514       │
# │ 46  │ "orange-yellow"       │ 26.6676          │ 15.4337       │
# │ 47  │ "greyish pink"        │ 26.6962          │ 25.6338       │
# │ 48  │ "pinkish grey"        │ 26.7432          │ 34.1795       │
# │ 49  │ "purplish red"        │ 26.7787          │ 24.8608       │
# │ 50  │ "purpley blue"        │ 27.3566          │ 26.1889       │
# │ 51  │ "reddish"             │ 27.5516          │ 26.1546       │
# │ 52  │ "deep teal"           │ 27.6974          │ 27.1666       │
# │ 53  │ "dark blue-green"     │ 28.5287          │ 27.9406       │
# │ 54  │ "brownish pink"       │ 28.6299          │ 28.1555       │
# │ 55  │ "pale red"            │ 28.8094          │ 28.0306       │
# │ 56  │ "purple-red"          │ 28.9147          │ 27.2307       │
# │ 57  │ "purpley pink"        │ 29.2189          │ 27.4911       │
# │ 58  │ "pale olive green"    │ 29.2331          │ 29.1838       │
# │ 59  │ "lightish blue"       │ 29.628           │ 29.1356       │
# │ 60  │ "pale grey"           │ 30.0453          │ 28.8397       │
# │ 61  │ "darkish blue"        │ 30.0652          │ 30.4888       │
# │ 62  │ "grey pink"           │ 30.19            │ 29.2957       │
# │ 63  │ "lightish green"      │ 30.4397          │ 27.5817       │
# │ 64  │ "greeny grey"         │ 30.4463          │ 31.3504       │
# │ 65  │ "greyish brown"       │ 30.5101          │ 30.4926       │
# │ 66  │ "light blue grey"     │ 30.8831          │ 30.8414       │
# │ 67  │ "pale"                │ 31.7265          │ 31.9492       │
# │ 68  │ "bluey green"         │ 31.9878          │ 31.8149       │
# │ 69  │ "tealish"             │ 32.17            │ 30.7628       │
# │ 70  │ "light light blue"    │ 32.2516          │ 32.3995       │
# │ 71  │ "brownish"            │ 32.8507          │ 31.3733       │
# │ 72  │ "darkish green"       │ 33.2844          │ 30.4074       │
# │ 73  │ "pale blue-green"     │ 33.3263          │ 29.7534       │
# │ 74  │ "greenish teal"       │ 33.3305          │ 31.304        │
# │ 75  │ "brownish green"      │ 33.3851          │ 27.827        │
# │ 76  │ "pinkish brown"       │ 33.987           │ 28.4099       │
# │ 77  │ "dull teal"           │ 34.3033          │ 35.0731       │
# │ 78  │ "pale brown"          │ 34.8888          │ 34.3671       │
# │ 79  │ "brown-green"         │ 35.0749          │ 28.964        │
# │ 80  │ "deep violet"         │ 35.4082          │ 35.6296       │
# │ 81  │ "red-purple"          │ 35.8531          │ 32.748        │
# │ 82  │ "lightish purple"     │ 36.3257          │ 31.6771       │
# │ 83  │ "violet red"          │ 36.4614          │ 29.3801       │
# │ 84  │ "light grey blue"     │ 36.9428          │ 35.8544       │
# │ 85  │ "greyish teal"        │ 37.3437          │ 36.5377       │
# │ 86  │ "deep green"          │ 37.3913          │ 36.975        │
# │ 87  │ "dark grey blue"      │ 38.0474          │ 37.1769       │
# │ 88  │ "purplish grey"       │ 38.2277          │ 35.226        │
# │ 89  │ "brownish grey"       │ 39.2355          │ 29.0025       │
# │ 90  │ "bluey grey"          │ 39.8013          │ 43.1446       │
# │ 91  │ "dark yellow-green"   │ 40.341           │ 35.0664       │
# │ 92  │ "greyish"             │ 40.9109          │ 40.843        │
# │ 93  │ "darkish purple"      │ 41.3831          │ 44.1901       │
# │ 94  │ "brown-grey"          │ 43.5272          │ 28.9296       │
# │ 95  │ "purple-brown"        │ 44.9147          │ 33.1879       │
# │ 96  │ "purplish brown"      │ 49.0214          │ 38.2411       │
# │ 97  │ "brownish purple"     │ 65.4723          │ 38.6549       │
# │ 98  │ "light greenish blue" │ 112.289          │ 27.733        │
# │ 99  │ "light green-blue"    │ 182.945          │ 39.1281       │
# │ 100 │ "dark blue-grey"      │ 201.946          │ 56.5166       │

# %%
plot_hsv(query(full_mdl, "lightish green")...)
# Out:
# (h_max,s_max,v_max) = (0.359375,0.515625,0.984375)
# WARNING: No working GUI backend found for matplotlib
# WARNING: No working GUI backend found for matplotlib
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(empiri_mdl, "lightish green")...)
# Out:
# (h_max,s_max,v_max) = (0.359375,0.71875,0.90625)
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(extrapo_mdl, "lightish green")...)
# Out:
# (h_max,s_max,v_max) = (0.296875,0.40625,0.984375)

# %%
plot_hsv(query(full_mdl, "purple")...)
# Out:
# (h_max,s_max,v_max) = (0.78125,0.984375,0.734375)
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(empiri_mdl, "purple")...)
# Out:
# (h_max,s_max,v_max) = (0.78125,0.984375,0.75)

# %%
plot_hsv(query(full_mdl, "brownish purple")...)
# Out:
# (h_max,s_max,v_max) = (1.0,0.984375,0.546875)
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(empiri_mdl, "brownish purple")...)
# Out:
# (h_max,s_max,v_max) = (1.0,0.328125,0.484375)
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(extrapo_mdl, "brownish purple")...)
# Out:
# (h_max,s_max,v_max) = (0.765625,0.984375,0.546875)
# <img src="data:image/png;base64,..." />

# %%
full_cldata.encoding
# Out:
# MLLabelUtils.LabelEnc.NativeLabels{SubString{String},311}(SubString{String}["acid","green","adobe","algae","almost","black","amber","amethyst","apple","apricot"  …  "vivid","vomit","warm","watermelon","weird","wheat","wine","wintergreen","wisteria","yuck"],Dict("russet"=>255,"celery"=>86,"lipstick"=>199,"dull"=>139,"chocolate"=>93,"sepia"=>263,"fern"=>152,"sickly"=>267,"y"=>44,"heliotrope"=>173…))

# %%
plot_hsv(query(full_mdl, "bright orange")...)
# Out:
# (h_max,s_max,v_max) = (0.0625,0.984375,0.984375)
# <img src="data:image/png;base64,..." />

# %%
plot_hsv(query(extrapo_mdl, "bright orange")...)
# Out:
# (h_max,s_max,v_max) = (0.078125,0.984375,0.984375)

# %%
plot_hsv(query(empiri_mdl, "bright orange")...)
# Out:
# (h_max,s_max,v_max) = (0.0625,0.984375,1.0)
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # Validation of the  Spread

# %%
df_spread = DataFrame(stddev=Float64[], perp=Float64[], mse_to_peak=Float64[], perp_sat=Float64[], perp_hue=Float64[], perp_val=Float64[])
for fn in glob(glob"../models/extrapolation/*/params.jld")
    res, std = load(fn, "dev_set_results", "splay_std_dev")
    res[:stddev] = std
    push!(df_spread, res)
end

df_spread[:stddev_in_bins] = df_spread[:stddev]*64
df_spread
# Out:
# 5×7 DataFrames.DataFrame
# │ Row │ stddev      │ perp    │ mse_to_peak │ perp_sat │ perp_hue │ perp_val │
# ├─────┼─────────────┼─────────┼─────────────┼──────────┼──────────┼──────────┤
# │ 1   │ 0.000976563 │ 26.8434 │ 0.187655    │ 42.1984  │ 15.1596  │ 30.2363  │
# │ 2   │ 0.00195313  │ 26.9459 │ 0.192534    │ 41.8061  │ 14.8907  │ 31.4286  │
# │ 3   │ 0.00390625  │ 26.972  │ 0.178995    │ 42.4426  │ 14.7273  │ 31.3917  │
# │ 4   │ 0.0078125   │ 26.4622 │ 0.171862    │ 41.1467  │ 14.3167  │ 31.4559  │
# │ 5   │ 0.015625    │ 27.3321 │ 0.184193    │ 42.8506  │ 15.1747  │ 31.401   │
#
# │ Row │ stddev_in_bins │
# ├─────┼────────────────┤
# │ 1   │ 0.0625         │
# │ 2   │ 0.125          │
# │ 3   │ 0.25           │
# │ 4   │ 0.5            │
# │ 5   │ 1.0            │
