# %%
using Plots
using Colors

# %%
using Plots; gr(grid = false, ms = 150, legend = false, msw = 0)
scatter([1,2],[1,1], c =["#5fafaf", "#7aa6da"], ms = 150, ylim = [0,2], xlim = [0,3])

# %%
pyplot(grid = false, ms = 150, legend = false, msw = 0)
scatter([1,2],[1,1], c =["#5fafaf", "#7aa6da"], ms = 150, ylim = [0,2], xlim = [0,3])
# Out:
# INFO: Recompiling stale cache file /home/wheel/oxinabox/.julia/lib/v0.6/PyPlot.ji for module PyPlot.
# Info: Installing matplotlib via the Conda matplotlib package...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /home/wheel/oxinabox/.julia/v0.6/Conda/deps/usr
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxcb-1.13                |                0         541 KB  conda-forge
#     kiwisolver-1.0.1           |           py27_1         932 KB  conda-forge
#     cycler-0.10.0              |           py27_0          13 KB  conda-forge
#     subprocess32-3.5.0         |           py27_0          57 KB  conda-forge
#     glib-2.53.6                |       h5d9569c_2         8.4 MB
#     pytz-2018.4                |             py_0         215 KB  conda-forge
#     icu-58.2                   |                0        22.7 MB  conda-forge
#     pyparsing-2.2.0            |           py27_0          92 KB  conda-forge
#     gst-plugins-base-1.12.4    |       h33fb286_0         4.8 MB
#     xz-5.2.3                   |                0         854 KB  conda-forge
#     functools32-3.2.3.2        |           py27_2          22 KB  conda-forge
#     pcre-8.41                  |                1         729 KB  conda-forge
#     singledispatch-3.4.0.3     |           py27_0          12 KB  conda-forge
#     jpeg-9b                    |                2         1.0 MB  conda-forge
#     pyqt-5.6.0                 |           py27_5         5.2 MB  conda-forge
#     dbus-1.11.0                |                0         1.6 MB  conda-forge
#     matplotlib-2.2.2           |           py27_1         9.0 MB  conda-forge
#     fontconfig-2.13.0          |                0         964 KB  conda-forge
#     libiconv-1.15              |                0         2.0 MB  conda-forge
#     qt-5.6.2                   |      h974d657_12        44.5 MB
#     python-dateutil-2.7.2      |             py_0         203 KB  conda-forge
#     libpng-1.6.34              |                0         305 KB  conda-forge
#     freetype-2.8.1             |                0         2.9 MB  conda-forge
#     expat-2.2.5                |                0         434 KB  conda-forge
#     backports_abc-0.5          |           py27_0           6 KB  conda-forge
#     libgcc-7.2.0               |       h69d50b8_2         304 KB
#     libuuid-1.0.3              |                1          34 KB  conda-forge
#     backports.functools_lru_cache-1.5|           py27_0          11 KB  conda-forge
#     xorg-libxau-1.0.8          |                3          14 KB  conda-forge
#     libxml2-2.9.8              |                0         5.0 MB  conda-forge
#     gstreamer-1.12.4           |       hb53b477_0         3.6 MB
#     sip-4.18                   |           py27_1         265 KB  conda-forge
#     xorg-libxdmcp-1.1.2        |                3          21 KB  conda-forge
#     tornado-5.0.2              |           py27_0         633 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       117.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     backports.functools_lru_cache: 1.5-py27_0        conda-forge
#     backports_abc:                 0.5-py27_0        conda-forge
#     cycler:                        0.10.0-py27_0     conda-forge
#     dbus:                          1.11.0-0          conda-forge
#     expat:                         2.2.5-0           conda-forge
#     fontconfig:                    2.13.0-0          conda-forge
#     freetype:                      2.8.1-0           conda-forge
#     functools32:                   3.2.3.2-py27_2    conda-forge
#     glib:                          2.53.6-h5d9569c_2
#     gst-plugins-base:              1.12.4-h33fb286_0
#     gstreamer:                     1.12.4-hb53b477_0
#     icu:                           58.2-0            conda-forge
#     jpeg:                          9b-2              conda-forge
#     kiwisolver:                    1.0.1-py27_1      conda-forge
#     libgcc:                        7.2.0-h69d50b8_2
#     libiconv:                      1.15-0            conda-forge
# libxcb 1.13########## | 100%
# kiwisolver 1.0.1########## | 100%
# cycler 0.10.0########## | 100%
# subprocess32 3.5.0########## | 100%
# glib 2.53.6########## | 100%
# pytz 2018.4########## | 100%
# icu 58.2########## | 100%
# pyparsing 2.2.0########## | 100%
# gst-plugins-base 1.12.4########## | 100%
# xz 5.2.3########## | 100%
# functools32 3.2.3.2########## | 100%
# pcre 8.41########## | 100%
# singledispatch 3.4.0.3########## | 100%
# jpeg 9b########## | 100%
# pyqt 5.6.0########## | 100%
# dbus 1.11.0########## | 100%
# matplotlib 2.2.2########## | 100%
# fontconfig 2.13.0########## | 100%
# libiconv 1.15########## | 100%
# qt 5.6.2########## | 100%
# python-dateutil 2.7.2########## | 100%
# libpng 1.6.34########## | 100%
# freetype 2.8.1########## | 100%
# expat 2.2.5########## | 100%
# backports_abc 0.5########## | 100%
# libgcc 7.2.0########## | 100%
# libuuid 1.0.3########## | 100%
# backports.functools_lru_cache 1.5########## | 100%
# xorg-libxau 1.0.8########## | 100%
# libxml2 2.9.8########## | 100%
# gstreamer 1.12.4########## | 100%
# sip 4.18########## | 100%
# xorg-libxdmcp 1.1.2########## | 100%
# tornado 5.0.2#########4 |  95%
#   libpng:                        1.6.34-0          conda-forge
#     libuuid:                       1.0.3-1           conda-forge
#     libxcb:                        1.13-0            conda-forge
#     libxml2:                       2.9.8-0           conda-forge
#     matplotlib:                    2.2.2-py27_1      conda-forge
#     pcre:                          8.41-1            conda-forge
#     pyparsing:                     2.2.0-py27_0      conda-forge
#     pyqt:                          5.6.0-py27_5      conda-forge
#     python-dateutil:               2.7.2-py_0        conda-forge
#     pytz:                          2018.4-py_0       conda-forge
#     qt:                            5.6.2-h974d657_12
#     singledispatch:                3.4.0.3-py27_0    conda-forge
#     sip:                           4.18-py27_1       conda-forge
#     subprocess32:                  3.5.0-py27_0      conda-forge
#     tornado:                       5.0.2-py27_0      conda-forge
#     xorg-libxau:                   1.0.8-3           conda-forge
#     xorg-libxdmcp:                 1.1.2-3           conda-forge
#     xz:                            5.2.3-0           conda-forge
#
#
# Downloading and Extracting Packages
# Preparing transaction: ...working...
# tornado 5.0.2########## | 100%
# done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# if !Plots.is_installed("PyPlot")
#     Pkg.add("PyPlot")
# end
# withenv("PYTHON" => "") do
#     Pkg.build("PyPlot")
# end
#
# # now restart julia!
# WARNING: Couldn't initialize pyplot.  (might need to install it?)
# INFO: To do a standard install of pyplot, copy and run this:
# InitError: PyError (PyImport_ImportModule
#
# The Python package matplotlib could not be found by pyimport. Usually this means
# that you did not install matplotlib in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the matplotlib module, you can
# use `pyimport_conda("matplotlib", PKG)`, where PKG is the Anaconda
# package the contains the module matplotlib, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# Alternatively, if you want to use a different Python distribution on your
# system, such as a system-wide Python (as opposed to the Julia-specific Python),
# you can re-configure PyCall with that Python.   As explained in the PyCall
# documentation, set ENV["PYTHON"] to the path/name of the python executable
# you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# ) <type 'exceptions.ImportError'>
# ImportError('No module named numpy',)
#   File "/home/wheel/oxinabox/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/__init__.py", line 127, in <module>
#     from . import cbook
#   File "/home/wheel/oxinabox/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/cbook/__init__.py", line 35, in <module>
#     import numpy as np
#
# during initialization of module PyPlot
